# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# List of counties ()
counties = ['kisii','kisumu','kitui','kwale','laikipia', 'lamu','machakos',
            'makueni','mandera','marsabit', 'meru','migori','mombasa','murang-a','nairobi-city','nakuru']  

# List of months
months = ['january', 'february', 'march', 'april', 'may', 'june', 
          'july', 'august', 'september', 'october', 'november', 'december']

# List of years from 2010 to 2011
# Loop through 2010 to 2011,save.
# Loop through 2012 to 2020 , save.
# Merge the two dataframes
years = list(range(2012, 2020))

# Initialize an empty DataFrame to store all data
all_data = pd.DataFrame()

# Loop through each county, year, and month
for county in counties:
    for year in years:
        for month in months:
            # Construct the URL
            url = f'https://weatherandclimate.com/{county}/{month}-{year}'
            
            # Send request to the URL
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Extract the first table containing the relevant data
            tables = soup.find_all('table')
            if tables:
                first_table = tables[0]  # Get the first table
                
                # Extract the relevant data from the first table
                temperature_data = {}
                rows = first_table.find_all('tr')
                for row in rows:
                    cells = row.find_all('td')
                    if len(cells) > 1:  # Ensure there are enough cells in the row
                        label = cells[0].text.strip()
                        value = cells[1].text.strip()
                        if 'Max Temperature' in label:
                            temperature_data['Max Temperature'] = value
                        elif 'Avg Temperature' in label:
                            temperature_data['Avg Temperature'] = value
                        elif 'Min Temperature' in label:
                            temperature_data['Min Temperature'] = value
                        elif 'Dew Point' in label:
                            temperature_data['Dew Point'] = value
                        elif 'Precipitation' in label:
                            temperature_data['Precipitation'] = value  # Adjusted to extract from cell 1
                        elif 'Wind' in label:
                            temperature_data['Wind'] = value
                        elif 'Sea Level Pressure' in label:
                            temperature_data['Sea Level Pressure'] = value
                
                # Append the extracted data to the DataFrame
                df = pd.DataFrame({
                    'County': [county],
                    'Month': [month.capitalize()],
                    'Year': [year],
                    'Max Temperature': [temperature_data.get('Max Temperature', None)],
                    'Avg Temperature': [temperature_data.get('Avg Temperature', None)],
                    'Min Temperature': [temperature_data.get('Min Temperature', None)],
                    'Dew Point': [temperature_data.get('Dew Point', None)],
                    'Precipitation': [temperature_data.get('Precipitation', None)],
                    'Wind': [temperature_data.get('Wind', None)],
                    'Sea Level Pressure': [temperature_data.get('Sea Level Pressure', None)]
                })
                
                all_data = pd.concat([all_data, df], ignore_index=True)

# Save the DataFrame to a CSV file
all_data.to_csv('Maize-Yield-data---Omdena-Local-chapter/Data/kenya_weather_data_2012_2020.csv', index=False)

print("Data extraction complete. Saved to 'kenya_weather_data_2010_2011.csv'.")
# Out:
# Data extraction complete. Saved to 'kenya_weather_data_2010_2011.csv'.

# %%
# Combine the files
df1 = pd.read_csv('Maize-Yield-data---Omdena-Local-chapter/Data/kenya_weather_data_2010_2011.csv')
df2 = pd.read_csv('Maize-Yield-data---Omdena-Local-chapter/Data/kenya_weather_data_2012_2020.csv')

# %%
# Merge the dataframes

merged_df = pd.concat([df1, df2], ignore_index=True)
merged_df.head()
# Out:
#   County     Month  Year  Max Temperature  Avg Temperature  Min Temperature  \
# 0  kisii   January  2010  29.0°C (84.2°F)  23.0°C (73.4°F)  18.0°C (64.4°F)
# 1  kisii  February  2010  30.0°C (86.0°F)  24.0°C (75.2°F)  19.0°C (66.2°F)
# 2  kisii     March  2010  28.0°C (82.4°F)  23.0°C (73.4°F)  18.0°C (64.4°F)
# 3  kisii     April  2010  26.0°C (78.8°F)  23.0°C (73.4°F)  17.0°C (62.6°F)
# 4  kisii       May  2010  25.0°C (77.0°F)  21.0°C (69.8°F)  17.0°C (62.6°F)
#
#          Dew Point    Precipitation                Wind Sea Level Pressure
# 0  18.0°C (64.4°F)  21.1mm | 0.83in   16.0kmh | 9.94mph             21.1mb
# 1  18.0°C (64.4°F)  61.3mm | 2.41in  18.0kmh | 11.18mph             61.3mb
# 2  18.0°C (64.4°F)  88.3mm | 3.48in   16.0kmh | 9.94mph             88.3mb
# 3  18.0°C (64.4°F)  95.3mm | 3.75in   12.0kmh | 7.46mph             95.3mb
# 4  18.0°C (64.4°F)  81.7mm | 3.22in    14.0kmh | 8.7mph             81.7mb

# %%
# Save the merged DataFrame to a new CSV file
merged_df.to_csv('Maize-Yield-data---Omdena-Local-chapter/Data/kenya_climate_data_2010_2020.csv', index=False)
